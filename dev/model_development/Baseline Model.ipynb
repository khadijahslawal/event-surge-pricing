# %% [markdown]
# # Model Development

# %%
# %pip install tensorflow matplotlib --quiet

# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import IntegerType
from pyspark.ml.feature import VectorAssembler

from pyspark.sql import functions as F
from pyspark.sql.window import Window
from pyspark.ml.functions import vector_to_array

from pyspark.ml.feature import VectorAssembler
from pyspark.ml import Pipeline

from pyspark.ml.regression import LinearRegression
from pyspark.ml.classification import GBTClassifier

from pyspark.ml.evaluation import RegressionEvaluator, BinaryClassificationEvaluator

# %%
spark = SparkSession.builder \
    .appName("Final Project Advanced Model") \
    .config("spark.jars", "gs://spark-lib/bigquery/spark-bigquery-latest_2.12.jar") \
    .getOrCreate()

# %%
final_path = "gs://msca-bdp-student-gcs/Group_1_final_project/curated/final_features" 
events_taxi_df = spark.read.parquet(final_path)

# %% [markdown]
# **Get the most busy zone**

# %%
# events_taxi_df.groupBy("PULocationID").agg(
#         F.sum(F.col("trip_count")).alias("sum")
#     ).orderBy("sum", ascending=False).show()
# Out:
# [Stage 1:===========================================>             (13 + 4) / 17]
# +------------+-------+
# |PULocationID|    sum|
# +------------+-------+
# |         161|2455341|
# |         237|2280101|
# |         236|1835086|
# |         186|1782760|
# |         162|1742994|
# |         230|1707065|
# |         138|1666951|
# |         163|1472952|
# |         142|1439463|
# |         170|1410807|
# |         234|1343727|
# |          68|1322331|
# |          48|1200222|
# |         239|1157558|
# |          43|1132719|
# |         164|1112757|
# |         249|1033037|
# |          79|1006890|
# |         141| 945925|
# |         132| 932973|
# +------------+-------+
# only showing top 20 rows

# %%
# Compute per-zone 90th percentile of trip_count
zone_q = (
    events_taxi_df
    .groupBy("PULocationID")
    .agg(F.expr("percentile_approx(trip_count, 0.90)").alias("q90"))
)

events_taxi_surge = events_taxi_df.join(zone_q, "PULocationID", "left")

# Binary surge label: 1 if trip_count > zone-specific 90th percentile
events_taxi_surge = events_taxi_surge.withColumn(
    "is_surge",
    (F.col("trip_count") > F.col("q90")).cast("int")
)

# %% [markdown]
# ### Class Balancing

# %%
# df_surge has the column "is_surge" (0 or 1)
class_counts = events_taxi_surge.groupBy("is_surge").count()

class_counts.show()
# Out:
# [Stage 5:====================================================>      (8 + 1) / 9]
# +--------+-------+
# |is_surge|  count|
# +--------+-------+
# |       1| 221468|
# |       0|2310894|
# +--------+-------+

# %%
counts = class_counts.rdd.collectAsMap()

n_neg = counts.get(0, 0)
n_pos = counts.get(1, 0)

print("Negative (no surge):", n_neg)
print("Positive (surge):   ", n_pos)
# Out:
# Negative (no surge): 2310894
# Positive (surge):    221468

# %%
pos_weight = n_neg / n_pos
print("Positive class weight =", pos_weight)
# Out:
# Positive class weight = 10.43443748080987

# %%
events_taxi_surge = events_taxi_surge.withColumn(
    "class_weight",
    F.when(F.col("is_surge") == 1, F.lit(pos_weight)).otherwise(F.lit(1.0))
)

# %%
drop_cols = [
    "borough",
    "event_borough",
    "weather_borough",
    "station_name",
    "season",
    "weather_date",
    "date"
]

events_taxi_surge_final = events_taxi_surge.drop(*[c for c in drop_cols if c in events_taxi_surge.columns])

# %% [markdown]
# ### Lag Features

# %%
w = Window.partitionBy("PULocationID").orderBy("half_hour")

events_taxi_surge_final = (
    events_taxi_surge_final
    .withColumn("lag1_trip_count", F.lag("trip_count", 1).over(w))
    .withColumn("lag2_trip_count", F.lag("trip_count", 2).over(w))
    .withColumn("lag4_trip_count", F.lag("trip_count", 4).over(w))
    .withColumn("rolling_mean_2hr",
        F.avg("trip_count").over(w.rowsBetween(-4, -1))
    )
)

events_taxi_surge_final = events_taxi_surge_final.fillna(
    {
        "lag1_trip_count": 0.0,
        "lag2_trip_count": 0.0,
        "lag4_trip_count": 0.0,
        "rolling_mean_2hr": 0.0
    }
)

# %%
# Ensure no null labels
events_taxi_surge_final = (
    events_taxi_surge_final
    .filter(F.col("trip_count").isNotNull())
    .filter(F.col("is_surge").isNotNull())
)

# %% [markdown]
# ### Train Test Split

# %%
# Identify numeric columns to impute (exclude labels)
numeric_impute_cols = [
    c for c, t in events_taxi_surge_final.dtypes
    if t in ("int", "bigint", "double") and c not in ("trip_count", "is_surge")
]

print("Imputing nulls in numeric columns:", len(numeric_impute_cols))

events_taxi_surge_final = events_taxi_surge_final.fillna(0, subset=numeric_impute_cols)
# Out:
# Imputing nulls in numeric columns: 57

# %%
# Columns that should NEVER go into features
exclude_cols = {
    "trip_count",      # regression label
    "is_surge",        # classification label
    "PULocationID",    # ID
    "half_hour",       # timestamp key
    "q90",             # threshold used to define is_surge
    "class_weight"     # sample weight, not feature
}

# Build feature_cols ON THE FULL df_ts
feature_cols = [
    c for c, t in events_taxi_surge_final.dtypes
    if t not in ("string", "timestamp") and c not in exclude_cols
]

print("Feature columns:", len(feature_cols))
# Out:
# Feature columns: 54

# %%
train_cutoff = "2024-01-01"
val_cutoff   = "2024-03-01"

train_df = events_taxi_surge_final.filter(F.col("half_hour") < train_cutoff)
val_df   = events_taxi_surge_final.filter((F.col("half_hour") >= train_cutoff) & (F.col("half_hour") < val_cutoff))
test_df  = events_taxi_surge_final.filter(F.col("half_hour") >= val_cutoff)

# %% [markdown]
# ### Feature Vectors

# %%
assembler = VectorAssembler(
    inputCols=feature_cols,
    outputCol="features",
    handleInvalid="keep"   # extra guardrail
)

# %% [markdown]
# ### GBT Classifer - Surge Prediction

# %%
gbt_cls = GBTClassifier(
    featuresCol="features",
    labelCol="is_surge",
    weightCol="class_weight",   # key for imbalance
    maxDepth=8,
    maxIter=80,
    stepSize=0.05,
    subsamplingRate=0.8
)

gbt_cls_pipeline = Pipeline(stages=[assembler, gbt_cls])
gbt_cls_model = gbt_cls_pipeline.fit(train_df)
# Out:
# 25/12/01 00:44:17 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1005.3 KiB
# 25/12/01 00:44:17 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1011.0 KiB
# 25/12/01 00:44:18 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1011.5 KiB
# 25/12/01 00:44:18 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1012.2 KiB
# 25/12/01 00:44:18 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1013.2 KiB
# 25/12/01 00:44:18 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1015.5 KiB
# 25/12/01 00:44:19 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1020.1 KiB
# 25/12/01 00:44:19 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1029.4 KiB
# 25/12/01 00:44:19 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1047.7 KiB
# 25/12/01 00:44:19 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1054.1 KiB
# 25/12/01 00:44:20 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1054.5 KiB
# 25/12/01 00:44:20 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1055.3 KiB
# 25/12/01 00:44:20 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1056.3 KiB
# 25/12/01 00:44:20 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1058.6 KiB
# 25/12/01 00:44:20 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1063.2 KiB
# 25/12/01 00:44:21 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1072.4 KiB
# 25/12/01 00:44:21 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1090.2 KiB
# 25/12/01 00:44:21 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1096.0 KiB
# 25/12/01 00:44:22 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1096.5 KiB
# 25/12/01 00:44:22 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1097.2 KiB
# 25/12/01 00:44:22 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1098.2 KiB
# 25/12/01 00:44:22 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1100.5 KiB
# 25/12/01 00:44:22 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1105.1 KiB
# 25/12/01 00:44:23 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1114.4 KiB
# 25/12/01 00:44:23 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1132.8 KiB
# 25/12/01 00:44:23 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1138.9 KiB
# 25/12/01 00:44:23 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1139.4 KiB
# 25/12/01 00:44:24 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1140.1 KiB
# 25/12/01 00:44:24 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1141.1 KiB
# 25/12/01 00:44:24 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1143.5 KiB
# 25/12/01 00:44:24 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1148.1 KiB
# 25/12/01 00:44:24 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1157.3 KiB
# 25/12/01 00:44:25 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1175.7 KiB
# 25/12/01 00:44:25 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1182.3 KiB
# 25/12/01 00:44:25 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1182.8 KiB
# 25/12/01 00:44:25 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1183.5 KiB
# 25/12/01 00:44:26 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1184.5 KiB
# 25/12/01 00:44:26 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1186.8 KiB
# 25/12/01 00:44:26 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1191.5 KiB
# 25/12/01 00:44:26 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1200.7 KiB
# 25/12/01 00:44:26 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1219.0 KiB
# 25/12/01 00:44:27 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1225.2 KiB
# 25/12/01 00:44:27 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1225.7 KiB
# 25/12/01 00:44:27 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1226.4 KiB
# 25/12/01 00:44:27 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1227.5 KiB
# 25/12/01 00:44:28 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1229.8 KiB
# 25/12/01 00:44:28 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1234.4 KiB
# 25/12/01 00:44:28 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1243.6 KiB
# 25/12/01 00:44:28 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1262.0 KiB
# 25/12/01 00:44:29 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1268.3 KiB
# 25/12/01 00:44:29 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1268.8 KiB
# 25/12/01 00:44:29 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1269.5 KiB
# 25/12/01 00:44:29 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1270.5 KiB
# 25/12/01 00:44:30 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1272.9 KiB
# 25/12/01 00:44:30 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1277.5 KiB
# 25/12/01 00:44:30 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1286.7 KiB
# 25/12/01 00:44:30 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1305.1 KiB
# 25/12/01 00:44:30 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1311.4 KiB
# 25/12/01 00:44:31 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1311.9 KiB
# 25/12/01 00:44:31 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1312.6 KiB
# 25/12/01 00:44:31 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1313.6 KiB
# 25/12/01 00:44:31 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1315.9 KiB
# 25/12/01 00:44:32 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1320.5 KiB
# 25/12/01 00:44:32 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1329.5 KiB
# 25/12/01 00:44:32 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1347.0 KiB
# 25/12/01 00:44:32 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1353.2 KiB
# 25/12/01 00:44:33 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1353.7 KiB
# 25/12/01 00:44:33 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1354.4 KiB
# 25/12/01 00:44:33 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1355.4 KiB
# 25/12/01 00:44:33 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1357.7 KiB
# 25/12/01 00:44:34 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1362.3 KiB
# 25/12/01 00:44:34 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1371.6 KiB
# 25/12/01 00:44:34 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1390.0 KiB
# 25/12/01 00:44:34 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1396.6 KiB
# 25/12/01 00:44:35 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1397.1 KiB
# 25/12/01 00:44:35 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1397.8 KiB
# 25/12/01 00:44:35 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1398.8 KiB
# 25/12/01 00:44:35 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1401.1 KiB
# 25/12/01 00:44:36 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1405.7 KiB
# 25/12/01 00:44:36 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1414.9 KiB
# 25/12/01 00:44:36 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1433.4 KiB
# 25/12/01 00:44:36 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1440.0 KiB
# 25/12/01 00:44:37 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1440.5 KiB
# 25/12/01 00:44:37 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1441.2 KiB
# 25/12/01 00:44:37 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1442.2 KiB
# 25/12/01 00:44:37 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1444.5 KiB
# 25/12/01 00:44:38 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1449.1 KiB
# 25/12/01 00:44:38 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1458.4 KiB
# 25/12/01 00:44:38 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1476.8 KiB
# 25/12/01 00:44:38 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1483.3 KiB
# 25/12/01 00:44:39 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1483.7 KiB
# 25/12/01 00:44:39 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1484.5 KiB
# 25/12/01 00:44:39 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1485.5 KiB
# 25/12/01 00:44:39 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1487.8 KiB
# 25/12/01 00:44:40 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1492.4 KiB
# 25/12/01 00:44:40 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1501.6 KiB
# 25/12/01 00:44:40 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1519.8 KiB
# 25/12/01 00:44:40 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1525.9 KiB
# 25/12/01 00:44:41 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1526.3 KiB
# 25/12/01 00:44:41 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1527.1 KiB
# 25/12/01 00:44:41 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1528.1 KiB
# 25/12/01 00:44:41 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1530.4 KiB
# 25/12/01 00:44:41 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1535.0 KiB
# 25/12/01 00:44:42 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1544.2 KiB
# 25/12/01 00:44:42 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1562.4 KiB
# 25/12/01 00:44:42 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1568.8 KiB
# 25/12/01 00:44:43 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1569.3 KiB
# 25/12/01 00:44:43 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1570.0 KiB
# 25/12/01 00:44:43 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1571.0 KiB
# 25/12/01 00:44:43 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1573.3 KiB
# 25/12/01 00:44:43 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1577.9 KiB
# 25/12/01 00:44:44 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1587.2 KiB
# 25/12/01 00:44:44 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1605.6 KiB
# 25/12/01 00:44:44 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1612.0 KiB
# 25/12/01 00:44:45 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1612.5 KiB
# 25/12/01 00:44:45 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1613.2 KiB
# 25/12/01 00:44:45 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1614.2 KiB
# 25/12/01 00:44:45 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1616.6 KiB
# 25/12/01 00:44:45 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1621.2 KiB
# 25/12/01 00:44:46 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1630.4 KiB
# 25/12/01 00:44:46 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1648.8 KiB
# 25/12/01 00:44:46 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1655.4 KiB
# 25/12/01 00:44:46 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1655.9 KiB
# 25/12/01 00:44:47 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1656.6 KiB
# 25/12/01 00:44:47 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1657.7 KiB
# 25/12/01 00:44:47 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1660.0 KiB
# 25/12/01 00:44:47 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1664.6 KiB
# 25/12/01 00:44:47 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1673.8 KiB
# 25/12/01 00:44:48 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1692.2 KiB
# 25/12/01 00:44:48 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1698.5 KiB
# 25/12/01 00:44:48 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1699.0 KiB
# 25/12/01 00:44:49 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1699.7 KiB
# 25/12/01 00:44:49 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1700.8 KiB
# 25/12/01 00:44:49 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1703.1 KiB
# 25/12/01 00:44:49 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1707.7 KiB
# 25/12/01 00:44:49 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1716.9 KiB
# 25/12/01 00:44:50 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1735.0 KiB
# 25/12/01 00:44:50 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1741.3 KiB
# 25/12/01 00:44:50 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1741.8 KiB
# 25/12/01 00:44:51 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1742.5 KiB
# 25/12/01 00:44:51 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1743.5 KiB
# 25/12/01 00:44:51 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1745.8 KiB
# 25/12/01 00:44:51 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1750.4 KiB
# 25/12/01 00:44:51 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1759.4 KiB
# 25/12/01 00:44:52 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1777.1 KiB
# 25/12/01 00:44:52 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1782.8 KiB
# 25/12/01 00:44:52 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1783.2 KiB
# 25/12/01 00:44:53 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1784.0 KiB
# 25/12/01 00:44:53 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1785.0 KiB
# 25/12/01 00:44:53 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1787.3 KiB
# 25/12/01 00:44:53 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1791.9 KiB
# 25/12/01 00:44:53 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1801.1 KiB
# 25/12/01 00:44:54 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1819.5 KiB
# 25/12/01 00:44:54 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1826.0 KiB
# 25/12/01 00:44:54 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1826.5 KiB
# 25/12/01 00:44:55 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1827.2 KiB
# 25/12/01 00:44:55 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1828.2 KiB
# 25/12/01 00:44:55 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1830.5 KiB
# 25/12/01 00:44:55 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1835.1 KiB
# 25/12/01 00:44:55 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1844.4 KiB
# 25/12/01 00:44:56 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1862.8 KiB
# 25/12/01 00:44:56 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1868.9 KiB
# 25/12/01 00:44:56 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1869.4 KiB
# 25/12/01 00:44:57 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1870.1 KiB
# 25/12/01 00:44:57 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1871.1 KiB
# 25/12/01 00:44:57 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1873.4 KiB
# 25/12/01 00:44:57 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1878.0 KiB
# 25/12/01 00:44:57 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1887.2 KiB
# 25/12/01 00:44:58 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1905.3 KiB
# 25/12/01 00:44:58 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1910.9 KiB
# 25/12/01 00:44:58 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1911.3 KiB
# 25/12/01 00:44:59 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1912.1 KiB
# 25/12/01 00:44:59 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1913.1 KiB
# 25/12/01 00:44:59 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1915.4 KiB
# 25/12/01 00:44:59 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1920.0 KiB
# 25/12/01 00:45:00 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1929.2 KiB
# 25/12/01 00:45:00 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1947.7 KiB
# 25/12/01 00:45:00 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1954.3 KiB
# 25/12/01 00:45:01 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1954.7 KiB
# 25/12/01 00:45:01 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1955.5 KiB
# 25/12/01 00:45:01 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1956.5 KiB
# 25/12/01 00:45:01 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1958.8 KiB
# 25/12/01 00:45:01 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1963.4 KiB
# 25/12/01 00:45:02 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1972.6 KiB
# 25/12/01 00:45:02 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1990.9 KiB
# 25/12/01 00:45:02 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1996.5 KiB
# 25/12/01 00:45:03 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1997.0 KiB
# 25/12/01 00:45:03 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1997.7 KiB
# 25/12/01 00:45:03 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 1998.8 KiB
# 25/12/01 00:45:03 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2001.1 KiB
# 25/12/01 00:45:04 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2005.7 KiB
# 25/12/01 00:45:04 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2014.9 KiB
# 25/12/01 00:45:04 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2033.3 KiB
# 25/12/01 00:45:04 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2039.6 KiB
# 25/12/01 00:45:05 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2040.1 KiB
# 25/12/01 00:45:05 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2040.8 KiB
# 25/12/01 00:45:05 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2041.8 KiB
# 25/12/01 00:45:05 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2044.1 KiB
# 25/12/01 00:45:06 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 25/12/01 00:45:06 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 25/12/01 00:45:06 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 25/12/01 00:45:06 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 25/12/01 00:45:07 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 25/12/01 00:45:07 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 25/12/01 00:45:07 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 25/12/01 00:45:08 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 25/12/01 00:45:08 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 25/12/01 00:45:08 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/12/01 00:45:08 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/12/01 00:45:09 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/12/01 00:45:09 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/12/01 00:45:09 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/12/01 00:45:09 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/12/01 00:45:10 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/12/01 00:45:10 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/12/01 00:45:10 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/12/01 00:45:10 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/12/01 00:45:11 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/12/01 00:45:11 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/12/01 00:45:11 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/12/01 00:45:11 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/12/01 00:45:12 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/12/01 00:45:12 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/12/01 00:45:12 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/12/01 00:45:12 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/12/01 00:45:13 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/12/01 00:45:13 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/12/01 00:45:13 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/12/01 00:45:14 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/12/01 00:45:14 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/12/01 00:45:14 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/12/01 00:45:14 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/12/01 00:45:15 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/12/01 00:45:15 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/12/01 00:45:15 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/12/01 00:45:16 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/12/01 00:45:16 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/12/01 00:45:16 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/12/01 00:45:16 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/12/01 00:45:16 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/12/01 00:45:17 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/12/01 00:45:17 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/12/01 00:45:17 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/12/01 00:45:18 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/12/01 00:45:18 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/12/01 00:45:18 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/12/01 00:45:18 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.3 MiB
# 25/12/01 00:45:19 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.3 MiB
# 25/12/01 00:45:19 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.3 MiB
# 25/12/01 00:45:19 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.3 MiB
# 25/12/01 00:45:20 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.3 MiB
# 25/12/01 00:45:20 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.3 MiB
# 25/12/01 00:45:20 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.3 MiB
# 25/12/01 00:45:20 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.3 MiB
# 25/12/01 00:45:21 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.3 MiB
# 25/12/01 00:45:21 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.3 MiB
# 25/12/01 00:45:21 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.3 MiB
# 25/12/01 00:45:21 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.3 MiB
# 25/12/01 00:45:22 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.3 MiB
# 25/12/01 00:45:22 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.3 MiB
# 25/12/01 00:45:22 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.3 MiB
# 25/12/01 00:45:23 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.3 MiB
# 25/12/01 00:45:23 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.3 MiB
# 25/12/01 00:45:23 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.3 MiB
# 25/12/01 00:45:23 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 25/12/01 00:45:24 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 25/12/01 00:45:24 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 25/12/01 00:45:24 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 25/12/01 00:45:25 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 25/12/01 00:45:25 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 25/12/01 00:45:25 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 25/12/01 00:45:25 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 25/12/01 00:45:26 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 25/12/01 00:45:26 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 25/12/01 00:45:26 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 25/12/01 00:45:27 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 25/12/01 00:45:27 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 25/12/01 00:45:27 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 25/12/01 00:45:27 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 25/12/01 00:45:28 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 25/12/01 00:45:28 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 25/12/01 00:45:28 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 25/12/01 00:45:29 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.4 MiB
# 25/12/01 00:45:29 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/12/01 00:45:29 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/12/01 00:45:29 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/12/01 00:45:30 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/12/01 00:45:30 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/12/01 00:45:30 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/12/01 00:45:30 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/12/01 00:45:31 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/12/01 00:45:31 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/12/01 00:45:31 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/12/01 00:45:32 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/12/01 00:45:32 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/12/01 00:45:32 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/12/01 00:45:32 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/12/01 00:45:33 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/12/01 00:45:33 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/12/01 00:45:33 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/12/01 00:45:34 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/12/01 00:45:34 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/12/01 00:45:34 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/12/01 00:45:34 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.6 MiB
# 25/12/01 00:45:35 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.6 MiB
# 25/12/01 00:45:35 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.6 MiB
# 25/12/01 00:45:35 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.6 MiB
# 25/12/01 00:45:36 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.6 MiB
# 25/12/01 00:45:36 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.6 MiB
# 25/12/01 00:45:36 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.6 MiB
# 25/12/01 00:45:36 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.6 MiB
# 25/12/01 00:45:37 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.6 MiB
# 25/12/01 00:45:37 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.6 MiB
# 25/12/01 00:45:37 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.6 MiB
# 25/12/01 00:45:38 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.6 MiB
# 25/12/01 00:45:38 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.6 MiB
# 25/12/01 00:45:38 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.6 MiB
# 25/12/01 00:45:38 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.6 MiB
# 25/12/01 00:45:39 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.6 MiB
# 25/12/01 00:45:39 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.6 MiB
# 25/12/01 00:45:39 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.6 MiB
# 25/12/01 00:45:39 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/12/01 00:45:40 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/12/01 00:45:40 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/12/01 00:45:40 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/12/01 00:45:41 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/12/01 00:45:41 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/12/01 00:45:41 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/12/01 00:45:41 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/12/01 00:45:42 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/12/01 00:45:42 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/12/01 00:45:42 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/12/01 00:45:43 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/12/01 00:45:43 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/12/01 00:45:43 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/12/01 00:45:43 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/12/01 00:45:44 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/12/01 00:45:44 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/12/01 00:45:45 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/12/01 00:45:45 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/12/01 00:45:45 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/12/01 00:45:45 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/12/01 00:45:46 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/12/01 00:45:46 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/12/01 00:45:46 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/12/01 00:45:46 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/12/01 00:45:47 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/12/01 00:45:47 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/12/01 00:45:47 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/12/01 00:45:48 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/12/01 00:45:48 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/12/01 00:45:48 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/12/01 00:45:48 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/12/01 00:45:49 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/12/01 00:45:49 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/12/01 00:45:50 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/12/01 00:45:50 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/12/01 00:45:50 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/12/01 00:45:50 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/12/01 00:45:51 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/12/01 00:45:51 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/12/01 00:45:51 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/12/01 00:45:52 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/12/01 00:45:52 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/12/01 00:45:52 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/12/01 00:45:52 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/12/01 00:45:53 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/12/01 00:45:53 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/12/01 00:45:53 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/12/01 00:45:54 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/12/01 00:45:54 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/12/01 00:45:54 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/12/01 00:45:55 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/12/01 00:45:55 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/12/01 00:45:55 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/12/01 00:45:55 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/12/01 00:45:56 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/12/01 00:45:56 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/12/01 00:45:56 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/12/01 00:45:57 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/12/01 00:45:57 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/12/01 00:45:57 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/12/01 00:45:57 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/12/01 00:45:58 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/12/01 00:45:58 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/12/01 00:45:58 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/12/01 00:45:59 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/12/01 00:45:59 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/12/01 00:45:59 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/12/01 00:46:00 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/12/01 00:46:00 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/12/01 00:46:00 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/12/01 00:46:00 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/12/01 00:46:01 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/12/01 00:46:01 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/12/01 00:46:01 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/12/01 00:46:02 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/12/01 00:46:02 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/12/01 00:46:02 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/12/01 00:46:02 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/12/01 00:46:03 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/12/01 00:46:03 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/12/01 00:46:03 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/12/01 00:46:04 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/12/01 00:46:04 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/12/01 00:46:04 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/12/01 00:46:05 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/12/01 00:46:05 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/12/01 00:46:05 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/12/01 00:46:05 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/12/01 00:46:06 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/12/01 00:46:06 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/12/01 00:46:06 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/12/01 00:46:07 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/12/01 00:46:07 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/12/01 00:46:07 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/12/01 00:46:08 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/12/01 00:46:08 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/12/01 00:46:08 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/12/01 00:46:09 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/12/01 00:46:09 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/12/01 00:46:09 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/12/01 00:46:09 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/12/01 00:46:10 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/12/01 00:46:10 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/12/01 00:46:10 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/12/01 00:46:11 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/12/01 00:46:11 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/12/01 00:46:11 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/12/01 00:46:12 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/12/01 00:46:12 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/12/01 00:46:12 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/12/01 00:46:13 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/12/01 00:46:13 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/12/01 00:46:13 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/12/01 00:46:14 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/12/01 00:46:14 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/12/01 00:46:14 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/12/01 00:46:14 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/12/01 00:46:15 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/12/01 00:46:15 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/12/01 00:46:15 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/12/01 00:46:16 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/12/01 00:46:16 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/12/01 00:46:17 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/12/01 00:46:17 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/12/01 00:46:17 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/12/01 00:46:17 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/12/01 00:46:18 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/12/01 00:46:18 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/12/01 00:46:18 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/12/01 00:46:19 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/12/01 00:46:19 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/12/01 00:46:19 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/12/01 00:46:20 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/12/01 00:46:20 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/12/01 00:46:20 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 25/12/01 00:46:20 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 25/12/01 00:46:21 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 25/12/01 00:46:21 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 25/12/01 00:46:21 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 25/12/01 00:46:22 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 25/12/01 00:46:22 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 25/12/01 00:46:22 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 25/12/01 00:46:23 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 25/12/01 00:46:23 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 25/12/01 00:46:23 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 25/12/01 00:46:24 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 25/12/01 00:46:24 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 25/12/01 00:46:24 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 25/12/01 00:46:25 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 25/12/01 00:46:25 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 25/12/01 00:46:25 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 25/12/01 00:46:26 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 25/12/01 00:46:26 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 25/12/01 00:46:26 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 25/12/01 00:46:27 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 25/12/01 00:46:27 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 25/12/01 00:46:27 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.5 MiB
# 25/12/01 00:46:27 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.5 MiB
# 25/12/01 00:46:28 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.5 MiB

# %%
model_path = "gs://msca-bdp-student-gcs/Group_1_final_project/Workspace/Data_pipelines/gbt_surge_model"

# Save the full trained pipeline model
gbt_cls_model.write().overwrite().save(model_path)
print("Model saved at:", model_path)
# Out:
# Model saved at: gs://msca-bdp-student-gcs/Group_1_final_project/Workspace/Data_pipelines/gbt_surge_model

# %%
val_preds_cls = gbt_cls_model.transform(val_df)

evaluator_auc = BinaryClassificationEvaluator(
    labelCol="is_surge",
    rawPredictionCol="rawPrediction",
    metricName="areaUnderROC"
)

val_auc = evaluator_auc.evaluate(val_preds_cls)
print("GBTClassifier – Validation AUC:", val_auc)
# Out:
# 25/12/01 00:47:51 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.5 MiB
# GBTClassifier – Validation AUC: 0.9560734062661168

# %%
val_probs = (
    val_preds_cls
    .withColumn("prob_array", vector_to_array("probability"))
    .select("is_surge", "prob_array")
)
eps = 1e-9

def metrics_for_threshold(th):
    preds_th = val_probs.withColumn(
        "pred_is_surge",
        (F.col("prob_array")[1] > F.lit(th)).cast("int")   # prob of class 1
    )
    
    tp = preds_th.filter("pred_is_surge = 1 AND is_surge = 1").count()
    fp = preds_th.filter("pred_is_surge = 1 AND is_surge = 0").count()
    fn = preds_th.filter("pred_is_surge = 0 AND is_surge = 1").count()
    
    precision = tp / (tp + fp + eps)
    recall    = tp / (tp + fn + eps)
    f1        = 2 * precision * recall / (precision + recall + eps)
    
    return precision, recall, f1

thresholds = [0.2, 0.3, 0.4, 0.5]

for th in thresholds:
    p, r, f1 = metrics_for_threshold(th)
    print(f"th={th:.2f}  precision={p:.3f}  recall={r:.3f}  f1={f1:.3f}")
# Out:
# 25/12/01 00:50:58 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 25/12/01 00:51:11 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 25/12/01 00:51:26 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# th=0.20  precision=0.248  recall=0.982  f1=0.396
# 25/12/01 00:51:30 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 25/12/01 00:51:34 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 25/12/01 00:51:37 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# th=0.30  precision=0.296  recall=0.965  f1=0.454
# 25/12/01 00:51:41 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 25/12/01 00:51:44 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 25/12/01 00:51:48 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# th=0.40  precision=0.342  recall=0.945  f1=0.502
# 25/12/01 00:51:52 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 25/12/01 00:51:55 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 25/12/01 00:51:59 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# [Stage 2079:================================================>     (16 + 2) / 18]
# th=0.50  precision=0.387  recall=0.913  f1=0.544

# %%
from pyspark.ml.functions import vector_to_array
from pyspark.sql import functions as F

best_th = 0.5  # chosen based on F1

val_with_probs = val_preds_cls.withColumn(
    "prob_array", vector_to_array("probability")
)

val_with_preds = val_with_probs.withColumn(
    "pred_is_surge_gbt",
    (F.col("prob_array")[1] > F.lit(best_th)).cast("int")
)

eps = 1e-9

tp = val_with_preds.filter("pred_is_surge_gbt = 1 AND is_surge = 1").count()
fp = val_with_preds.filter("pred_is_surge_gbt = 1 AND is_surge = 0").count()
fn = val_with_preds.filter("pred_is_surge_gbt = 0 AND is_surge = 1").count()

precision = tp / (tp + fp + eps)
recall    = tp / (tp + fn + eps)
f1        = 2 * precision * recall / (precision + recall + eps)

print("FINAL (validation) – th =", best_th)
print("Precision:", precision)
print("Recall:   ", recall)
print("F1:       ", f1)
# Out:
# 25/12/01 00:53:17 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 25/12/01 00:53:22 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 25/12/01 00:53:27 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# [Stage 2106:=================================================>      (8 + 1) / 9]
# FINAL (validation) – th = 0.5
# Precision: 0.3872531200775359
# Recall:    0.9125562138624518
# F1:        0.5437570443063383

# %%
# Get test predictions from your saved/loaded model
test_preds_cls = gbt_cls_model.transform(test_df)

test_with_probs = test_preds_cls.withColumn(
    "prob_array", vector_to_array("probability")
)

test_with_preds = test_with_probs.withColumn(
    "pred_is_surge_gbt",
    (F.col("prob_array")[1] > F.lit(best_th)).cast("int")
)

tp_t = test_with_preds.filter("pred_is_surge_gbt = 1 AND is_surge = 1").count()
fp_t = test_with_preds.filter("pred_is_surge_gbt = 1 AND is_surge = 0").count()
fn_t = test_with_preds.filter("pred_is_surge_gbt = 0 AND is_surge = 1").count()

precision_t = tp_t / (tp_t + fp_t + eps)
recall_t    = tp_t / (tp_t + fn_t + eps)
f1_t        = 2 * precision_t * recall_t / (precision_t + recall_t + eps)

print("TEST – th =", best_th)
print("Precision:", precision_t)
print("Recall:   ", recall_t)
print("F1:       ", f1_t)
# Out:
# 25/12/01 00:53:54 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 25/12/01 00:54:14 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 25/12/01 00:54:23 WARN org.apache.spark.scheduler.DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# [Stage 2133:===================================================>  (17 + 1) / 18]
# TEST – th = 0.5
# Precision: 0.4530585524779987
# Recall:    0.9102003364428719
# F1:        0.6049827365038947

# %% [markdown]
# ## Model Insights from Test set

# %% [markdown]
# **Recall is extremely high (91%)**
#
# The model correctly identifies 9 out of 10 actual surge periods, which is exactly what we’d want in a real ride-hailing system:
# - Missing true surges leads to underpricing + lost revenue + unhappy drivers
# - Flagging too many false surges leadss to light inefficiencies, but tolerable
#
# So high recall is desirable.
#
# **Precision is very reasonable (45%) in an imbalanced setting**
#
# Given surge is only ~8–10% of the data, a naïve model might have precision below 10%.
#
# 45% precision is actually very good:
# - When the model predicts “surge”, 45% of the time it’s correct.
# - That’s more than 4× better than random guessing at the base rate.
#
# **F1 score (0.605) is strong**
#
# An F1 ≈ 0.60 is quite solid for:
# - imbalanced data
# - time-series structured
# - noisy weather + event + taxi interactions
# - only half-hour granularity

# %% [markdown]
# ### Surge Prediction Model Results
#
# We evaluated the final surge classifier on the held-out test set using the tuned threshold of 0.50, selected during validation based on the F1 score. The model achieved:
# - Precision: 0.453
# - Recall: 0.910
# - F1 Score: 0.605
#
# Despite the underlying class imbalance (surge represents only ~9% of all half-hour × zone observations), the model demonstrates strong performance. The high recall indicates that the classifier successfully identifies the vast majority of actual surge periods (≈91%), which aligns with the operational objective of minimizing missed surges. While precision is lower (≈45%), this is substantially above the surge base rate and reflects acceptable trade-offs: falsely predicting a surge primarily leads to conservative staffing or pricing adjustments, whereas failing to detect a true surge can cause supply shortages and revenue loss.
#
# The F1 score of 0.605 represents a solid balance between precision and recall and shows no evidence of overfitting, improving from validation (0.544) to test (0.605). This suggests that the model generalizes well and captures meaningful signals from weather, events, and lagged taxi activity patterns.
